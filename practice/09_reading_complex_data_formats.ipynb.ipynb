# %%
# Read Parquet Sales data
df_parquet = spark.read.format("parquet").load("/Workspace/Users/miketyson.rocks69@gmail.com/PySpark_Practice_Set/practice/sales_data.parquet")

# %%
df_parquet.printSchema()

# %%
display(df_parquet)

# %%
# Read ORC Sales data
df_orc = spark.read.format("orc").load("/Workspace/Users/miketyson.rocks69@gmail.com/PySpark_Practice_Set/practice/*.orc")
df_orc.printSchema()

# %%
df_orc.show()

# %%
# Benefits of Columnar Storage

# Lets create a simple Python decorator - {get_time} to get the execution timings

import time

def get_time(func):
    def inner_get_time() -> str:
        start_time = time.time()
        func()
        end_time = time.time()
        return (f"Execution time: {(end_time - start_time)*1000} ms")
    print(inner_get_time())

# %%
@get_time
def x():
    df = spark.read.format("parquet").load("/Workspace/Users/miketyson.rocks69@gmail.com/PySpark_Practice_Set/practice/sales_data.parquet")
    df.count()

# %%
@get_time
def x():
    df = spark.read.format("parquet").load("/Workspace/Users/miketyson.rocks69@gmail.com/PySpark_Practice_Set/practice/sales_data.parquet")
    df.select("trx_id").count()
