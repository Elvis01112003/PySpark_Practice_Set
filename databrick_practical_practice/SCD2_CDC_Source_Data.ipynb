# %%
# %sql
CREATE OR REPLACE TABLE workspace.default.customer_cdc (
    customer_id INT,
    name STRING,
    city STRING,
    email STRING,
    operation STRING,
    sequence_num INT
)
USING DELTA;

# %%
# %sql
INSERT INTO workspace.default.customer_cdc VALUES
(101, 'John',  'Mumbai', 'john@gmail.com',  'INSERT', 1),
(102, 'Alice', 'Pune',   'alice@gmail.com', 'INSERT', 2),
(101, 'John',  'Pune',   'john@gmail.com',  'UPDATE', 3),
(103, 'David', 'Delhi',  'david@gmail.com', 'INSERT', 4);

# %%
# %sql
SELECT *
FROM workspace.default.customer_cdc
ORDER BY sequence_num;

# %%
# %sql
SELECT *
FROM workspace.default.customer_history
ORDER BY customer_id, __START_AT;

# %%
# %sql
INSERT INTO workspace.default.customer_cdc VALUES
(101, 'John', 'Delhi', 'john@gmail.com', 'UPDATE', 5);

# %%
# %sql
SELECT *
FROM workspace.default.customer_history
WHERE customer_id = 101
ORDER BY __START_AT;

# %%
# %sql
select current_user
